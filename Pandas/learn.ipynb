# %%
import pandas as pd

data = pd.read_csv('./datasets/Real estate.csv')

# %%
data.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
print(data[['X2 house age', 'X4 number of convenience stores']].head())
# Out:
#    X2 house age  X4 number of convenience stores
# 0          32.0                               10
# 1          19.5                                9
# 2          13.3                                5
# 3          13.3                                5
# 4           5.0                                5

# %%
data.iloc[0:2]
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2

# %%
data.iloc[0,2]
# Out:
# 32.0

# %%
for index, row in data.iterrows():
    print(index, row['X2 house age'])
# Out:
# 0 32.0
# 1 19.5
# 2 13.3
# 3 13.3
# 4 5.0
# 5 7.1
# 6 34.5
# 7 20.3
# 8 31.7
# 9 17.9
# 10 34.8
# 11 6.3
# 12 13.0
# 13 20.4
# 14 13.2
# 15 35.7
# 16 0.0
# 17 17.7
# 18 16.9
# 19 1.5
# 20 4.5
# 21 10.5
# 22 14.7
# 23 10.1
# 24 39.6
# 25 29.3
# 26 3.1
# 27 10.4
# 28 19.2
# 29 7.1
# 30 25.9
# 31 29.6
# 32 37.9
# 33 16.5
# 34 15.4
# 35 13.9
# 36 14.7
# 37 12.0
# 38 3.1
# 39 16.2
# 40 13.6
# 41 16.8
# 42 36.1
# 43 34.4
# 44 2.7
# 45 36.6
# 46 21.7
# 47 35.9
# 48 24.2
# 49 29.4
# 50 21.7
# 51 31.3
# 52 32.1
# 53 13.3
# 54 16.1
# 55 31.7
# 56 33.6
# 57 3.5
# 58 30.3
# 59 13.3
# 60 11.0
# 61 5.3
# 62 17.2
# 63 2.6
# 64 17.5
# 65 40.1
# 66 1.0
# 67 8.5
# 68 30.4
# 69 12.5
# 70 6.6
# 71 35.5
# 72 32.5
# 73 13.8
# 74 6.8
# 75 12.3
# 76 35.9
# 77 20.5
# 78 38.2
# 79 18.0
# 80 11.8
# 81 30.8
# 82 13.2
# 83 25.3
# 84 15.1
# 85 0.0
# 86 1.8
# 87 16.9
# 88 8.9
# 89 23.0
# 90 0.0
# 91 9.1
# 92 20.6
# 93 31.9
# 94 40.9
# 95 8.0
# 96 6.4
# 97 28.4
# 98 16.4
# 99 6.4
# 100 17.5
# 101 12.7
# 102 1.1
# ...

# %%
data.loc[data['X2 house age'] == 'NaN' ]
# Out:
# Empty DataFrame
# Columns: [No, X1 transaction date, X2 house age, X3 distance to the nearest MRT station, X4 number of convenience stores, X5 latitude, X6 longitude, Y house price of unit area]
# Index: []

# %%
data.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
data.sort_values(['X2 house age'], ascending=False).head()
# Out:
#       No  X1 transaction date  X2 house age  \
# 192  193             2013.167          43.8
# 392  393             2013.083          42.7
# 361  362             2013.083          41.4
# 128  129             2013.083          41.3
# 173  174             2013.083          41.3
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 192                                57.58945                                7
# 392                               443.80200                                6
# 361                               281.20500                                8
# 128                               124.99120                                6
# 173                               401.88070                                4
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 192     24.96750     121.54069                        42.7
# 392     24.97927     121.53874                        35.3
# ...
